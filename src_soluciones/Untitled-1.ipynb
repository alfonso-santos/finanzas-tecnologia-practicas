# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import yfinance as yf

# %%
symbols = ['SPY', 'GLD', 'AAPL', 'MSFT']

# %%
prices = yf.download(symbols, start='2010-01-01', end='2020-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
returns = np.log(prices).diff().dropna()

# %%
np.sum(pesos, axis=1).shape
# Out:
# (10000,)

# %%
num_carteras = 10000
num_activos = 4
pesos = np.random.random((num_carteras, num_activos))
pesos = pesos / np.sum(pesos, axis=1, keepdims=True)
pesos.shape
# Out:
# (10000, 4)

# %%
ret_port = returns @ pesos.T

ret_mean = ret_port.mean(axis=0)
ret_std = ret_port.std(axis=0)

# %%
plt.scatter(ret_std, ret_mean, c=ret_mean / ret_std, marker='o', cmap='coolwarm')
